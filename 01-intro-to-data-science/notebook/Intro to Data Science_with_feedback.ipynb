# %% [markdown]
# ## Description
#
# Learn what Data Science actually means sans the buzzwords - what it can do, what it can't do. Also learn what being a data scientist actually means and a brief look into the data science pipeline.
#
#
# ## Overview
#
# - Use cases of Data Science
# - Why Data Science
# - What is Machine Learning?
# - Types of Machine Learning?
# - Machine Learning Workflow
#
#
# ## Learning Objectives
#
# - Learn what Data Science truly is.
# - When Data Science is useful, and when it isn't?
# - Learn an overview of Machine Learning
# - Map the journey from learner to a complete Data Scientist
#
#
# ## Pre-requisites
#
# - Enthusiasm and Curiosity :)

# %% [markdown]
# ## 1. Data Science Around us.

# %% [markdown]
# ## 1.1 Tech use cases

# %% [markdown]
# ![world logos](../images/world_logos.jpg)

# %% [markdown]
# It is not an exaggeration to say that the world we live in is getting redefined by Data Science...
# - We might use Amazon/any e-commerce site to shop
# - We might use Uber/any travel aggregator to travel
# - We might use Siri/Alexa/Google assistant on our smartphone to ask questions and do tasks.
# - We might use Facebook/LinkedIn/any social network for connecting.
# Every one of these has data science in the backend.
#
# Even if you don't do any of these
# - If you have taken a flight, you are a beneficiary of data science.
# - If you are driving a car, most probably you are a beneficiary of data science.
# - If you are using any FMCG product, you are a benificiary of data science.
#
# Let's look at some general use cases of Data Science in various organizations
#
# ### Amazon
#
# ![alexa](../images/amazon_alexa.jpg)
#
# - Alexa is built on far-field speech recognition - interpreting voice spoken far from the microphone.
#
# ![Amazon Go](../images/amazon-go.jpg)
#
# - Amazon Go - cashierless check out store having data science in the background.
#
# For more interesting things that Amazon is working on and to know more, refer to this [article](https://www.wired.com/story/amazon-artificial-intelligence-flywheel/)
#
# ### Google
#
# ![google-assistant](../images/google-assistant.png)
#
# - Google assistant is now multilingual. Irrespective of the language you are giving instructions in, the assistant will figure out what you are trying to say.
#
# ![multilingual](../images/assistant-multilingual.png)
#
# - Smart Linkify - Automatically provide links for texts in messages for Android Pie.
#
# ![linkify](../images/linkify.gif)
#
# More interesting things that google is working on w.r.t data science can be read [here](https://ai.googleblog.com/)
#
# ### Facebook
#
# ![text-desc](../images/alt-text.png)
#
# - Generating [text for images](https://research.fb.com/do-jobs-run-in-families/) to describe them to visually impaired people.
#
# ![father-son](../images/father-son.png)
#
# - Answering interesting social questions like how much is the [choice of our profession](https://research.fb.com/do-jobs-run-in-families/) dependent on who our parents are.
#
# ### Uber
#
# - Surge price predictor is an ongoing use case. Another interesting use case of Data Science at Uber is the restaurant [delivery estimate for UberEats](https://eng.uber.com/michelangelo/).
#
# ![uber-eats](../images/uberEats.png)
#
#
# ### Airbnb
#
# - Airbnb uses data science to automatically [classify images](https://medium.com/airbnb-engineering/categorizing-listing-photos-at-airbnb-f9483f3ab7e3) of different parts of home as - bedroom, living room, etc to inform the users about listings in a better manner.
# ![airbnb1](../images/airbnb.png)
#
# - They also use data science to predict important parameters for [optimal pricing](https://medium.com/airbnb-engineering/learning-market-dynamics-for-optimal-pricing-97cffbcc53e3).
# ![airbnb2](../images/airbnb-pricing.png)
#
#
# ### IBM Watson
#
# - IBM Watson has entered into a [partnership with US Open](https://www.ibm.com/blogs/watson/2018/08/watson-powers-us-open-experiences-for-millions-of-tennis-fans/) to provide AI-powered highlights and also provide tools for better engagement.
#
# ![us-open](../images/slamtracker-portrait.png)
#
# These use cases are just a small sample of the large world. These are the general use cases for tech companies. What about other industries? Data science is ubiquitous in the true sense of the word and is making its way to core industries too.

# %% [markdown]
# ## 1.2 Core Industry use cases

# %% [markdown]
# ### Airbus
#
# ![airbus](../images/airbus.jpg)
#
# - [Airbus is using data science](https://aibusiness.com/how-is-ai-changing-the-aviation-industry/) to process data coming from various factories, and predicting when there is change in manufacturing process, so that possible problems could be premptively detected and solved.
#
# - They also leverage social media to understand passenger experience.
#
# ### Kraft Heinz
#
# ![kraftheinz](../images/heinzkraftbrands.jpg)
#
# - [Kraft Heinz has invested in Data Science](https://blogs.wsj.com/cio/2017/10/03/kraft-heinz-cio-spends-on-ai-robots-to-cut-costs/) to optimize costs and cut inefficiences in supply and marketing.
#
# ### Pfizer
#
# ![pfizer](../images/pfizer.jpeg)
#
# [Pfizer is partnering with IBM Watson](https://www.pfizer.com/news/press-release/press-release-detail/ibm_and_pfizer_to_accelerate_immuno_oncology_research_with_watson_for_drug_discovery) to integrate Data science and provide meaningful insights to scientists to aid drug discovery.
#
#
# ### United Nations
#
# ![unite](../images/united_nations.jpg)
#
# United Nations has an in-house analytics team and regularly conduct challenges for the data science community to solve problems of social relevance. [One of the challenges](https://www.un.org/press/en/2018/pi2221.doc.htm) to identify drinking water sources in Liberia.
#
# ### Goldman Sachs
#
# ![gs](../images/gs-pic.jpeg)
#
# [Goldman Sachs uses data science](https://www.gsam.com/content/gsam/global/en/market-insights/gsam-insights/gsam-perspectives/2016/big-data/gsam-roundtable.html) to get insights into investment themes such as momentum, value and profitability.
#
# ![gs table](../images/gm-ds.png)
#
# Here we have seen, how, in other industries too Data Science is playing a major role to improve processes. And many many startups are using data science under their hood to improve their product offerings.
#
# ### But...
#
# Sometimes even data science could be wrong. Like all tools, even data science could be wrong, and worse could even be misused.
#
# Before the football world cup 2018, there was data science prediction done on the [probable world cup winner](https://www.technologyreview.com/s/611397/machine-learning-predicts-world-cup-winner/).
# ![world-cup](../images/world-cup-2018.jpg)
# If you see the picture, Germany was predicted to be the eventual winner, but they were eliminated in the first round itself.
#
# ![scandal](../images/scandal.jpg)
# The [Facebook Cambridge Analytica scandal](https://en.wikipedia.org/wiki/Facebook%E2%80%93Cambridge_Analytica_data_scandal) is a glaring example of misuse of data science where personal data of 87 million users of Facebook was mined illegally and used for targeted advertising in political campaigns.
#
# We have looked at different use cases of data science in general. Now let's look at some surprising use cases - places where you think have nothing to do with data science.
#
# Now that we have seen the various use cases of Data Science, let us go a little deep into what Data Science truly means.

# %% [markdown]
# ## Quiz
#
# 1. Which industry uses Data Science to improve their productivity?
#
#     a. Google
#     b. Pfizer
#     c. Airbus
#     d. All of the above
#
# Ans. d. All of the above
#
# 2. Which domain of industry uses Data Science in their backend?
#
#     a. Technology
#     b. FMCG
#     c. Finance
#     d. All of the above
#
# Ans. d. All of the above

# %% [markdown]
# #### FEEDBACK:
# We may not need a quiz here, we can do away with this quiz.

# %% [markdown]
# ## 2. Deciphering Data Science

# %% [markdown]
# ## 2.1 The Data Explosion
#
#
#  ![google-trends](../images/google-trends.png) *Google trends of term data science from 2008*
#
# One way to gauge the popularity of data science is to look at google trends from the past few years for data science. There is a clear upward trend in the growth of data science. Why is it so?
#
#  ![cambrian](../images/cambrian_exp.jpg)  *The explosion of data. Source: Patrick Cheesman*
#
# The science in Data Science has been around from quite some time, but it is the growth of data in recent years that has really put the field at the forefront. Past few years have seen a huge explosion in the volumes of data being generated. [The Economist in 2010](https://www.economist.com/leaders/2010/02/25/the-data-deluge) reported about how data generation is increasing multifold year-on-year. Other features contributing to the rise of data science are
# - Data collection is getting cheaper.
# - It is becoming easier to store data.
# - New channels of data generation are opening up.
#
# The wearables market is giving more points to collect data - smart shoes, smart watches and smart home solutions are generating huge volumes of data and pointing to the next big explosion in data.
#
#  ![IoT-bigdata](../images/IoT.jpeg)  *Big data from IoT. Source: Patrick Cheesman*
#
# With the volumes of data coming in, there is a great need of expert data scientists to make sense of this data. What is a data scientist expected to do? What is the role of a data scientist? We will answer this question in the next topic.

# %% [markdown]
# ## 2.2 Data Scientists - what do they do?
#
# Talk to 10 different people, and you would get 10 different definitions of who a data scientist is. One of the informal definitions of data scientist would be:
#
# >Data Scientist (n.): Person who is better at statistics than any software engineer and better at software engineering than any statistician. — Josh Wills (@josh_wills) May 3, 2012
#
# ![venn-diag](../images/Data_Science_VD.png)
#
# While there is a lot of debate on the required skills and expertise for a data scientist, the Drew Conway Venn diagram is widely accepted as a good starting point. From the diagram, it is clear that a Data Scientist is an amalgamation of 3 different roles - Statistician, Domain Expert and Programmer. The danger zone is the intersection of Domain expertise and Programming without statistical backing which might lead to wrong insights.
#
# The ingenuity of a data scientist lies in solving problems using data from sources not directly related to the problem. A very good example of this is the [predictive policing](http://www.sciencemag.org/news/2016/09/can-predictive-policing-prevent-crime-it-happens) program. Using social media profiles of past criminals, models can be built to identify people at risk. Instead of directly using only the crime related data, the social media presence is also leveraged.
#
# ![predPolice](../images/PredictivePolicing.png)
#
# Now having looked broadly at Data Science - what it can do and what a data scientist is supposed to do. Now let's look closer at one of the main skills in data science, which is at the intersection of programming and statistics - machine learning.

# %% [markdown]
# ## 3. What is Machine Learning?

# %% [markdown]
# ## 3.1 Basic intuition
#
# Again, like data science, the definition of Machine learning(ML) is up for debate. One of the widely accepted definitions has been provided by Arthur Samuels.
#
# > Machine learning is the field of study that gives computers the ability to learn without being explicitly programmed. - Arthur Samuels (1959)
#
# First let us understand the difference between a traditional computer program and a machine learning program. We will understand the differences through an example. Suppose we are trying to program how to recognise a car from a set of images. A typical traditional program would help you identify a car through a set of rules. General rules for a car are
# - it has wheels
# - it has headlight.
# - it has steering wheel
#
# ![car_rules](../images/cars_rules.png)
#
# Then for a computer program, you can make the algorithm,
# if it has wheels AND if it has headlight AND if it has steering wheel
# Think of all the rules you need to list down to make the computer program work. It would be really CUMBERSOME. Also the program might fail if the images are of a different orientation.
#
# ![car_diff_angles](../images/car_diff.png)
#
# On the other hand, think of a scenario where you can just pass on the different images of car to a program, along with some data to help identify the car and then allow the program to figure out the rest of the rules by itself. This is a typical ML program - which given enough data will generalize and figure out the rest of the rules by itself.
#
# So the difference between a traditional computer program and ML program is as follows:-
# > **Traditional Algorithm** - clear set of instructions to which we give input and get a desired output. A rule-based approach.
# >  **ML Algorithm** - give a set of data and let the algorithm figure out patterns and rules to apply for future inputs.
#
# So you could say that the ML algorithm becomes better as we give more data on which it can learn more patterns. But do we apply machine learning on every kind of problem? Let us analyze that in the coming chapter.

# %% [markdown]
# #### FEEDBACK
# We should talk about rules based system for a bit and how they differ from ML based approaches - scale, generalizability etc. The first computer to beat chess grandmasters (forget the name), was a bunch of rules stacked together. They are called `expert systems`, and are still in vogue.
#
# We also need to draw more points on `WHY ML`, and explain to the learner the basic foundations of ML. Refer: https://homes.cs.washington.edu/~pedrod/papers/cacm12.pdf

# %% [markdown]
# ## Quiz
#
# 1. Which of the following statements uses a Machine Learning Model?
#
#   - Determine whether an incoming email is spam or not
#   - Obtain the name of team that won the last T20 World Cup
#   - Automatically tagging your new Facebook photos
#   - Select the student with the highest grade on a Creative Writing course
#
# Ans. 1 and 3

# %% [markdown]
# ## 3.2 Misconceptions about Machine Learning
#
# Before we deep dive into the various aspects of Machine Learning, it is important to do a sanity check on the popular misconceptions surrounding ML.
#
# ### Myth 1 - Machines can learn autonomously
# For the machines to be successful and provide right insights on data, a lot of work needs to be done by human on data to get it ready. True autonomous learning in not possible and human cannot be completely removed from the equation. For example, look at report in Financial Times on how [self-driving cars are proving to be labor intensive](https://www.ft.com/content/36933cfc-620c-11e7-91a7-502f7ee26895).
#
# ### Myth 2 - Machine learning can be applied to any task
#
# > Surprisingly, despite AI’s breadth of impact, the types of it being deployed are still extremely limited. Almost all of AI’s recent progress is through one type, in which some input data (A) is used to quickly generate some simple response (B). - Andrew Ng 2016 (Source: HBR)
#
# Nothing summarizes the response to the myth better than these words of Andrew Ng, one of the pioneers in ML. Read more on his thoughts on this subject [here](https://hbr.org/2016/11/what-artificial-intelligence-can-and-cant-do-right-now). Also, ML cannot be applied effectively when collection of data is very difficult like in health domains.
#
# On the other side of the coin, a lot of problems in industry can be solved through simple data summarization and analysis and don't need AI. Why use complicated statistical models to solve problems which could be solved by simple rules.
#
# ### Myth 3 - Once data is fed, Machine learning will give transformational insights
#
# A popular myth is that once you feed the algorithm data, actionable insights will emerge like the pot of gold at the edge of the rainbow. It is exactly that - a mirage. For every data generated, defining the problem to solve is very hard and it is a continuous iterative process of refining data and rebuilding models.
#
# ### Myth 4 - Machine Learning will give rise to superhuman intelligence
#
# Machines are as intelligent as the humans who programmed it. Inspite of all the advancement, machines don't have common sense and it cannot be taught the same. Don't worry - your smartphone won't take over the world and enslave you. EVER!
#
# Now that you have overcome the fear of machines taking over the world, let's look formally at the different types of ML.

# %% [markdown]
# ## Quiz
#
# 1. Can machines learn autonomously without any human intervention?
#
#     a. Yes
#     b. No
#
# Ans. b. No
#
# 2. Machine Learning cannot be applied to every kind of task
#
#     a. True
#     b. False
#
# Ans a. True

# %% [markdown]
# ## 4. Types of Machine Learning

# %% [markdown]
# ## 4.1 Supervised ML
#
# - For ML algorithms, like any other algorithms, you give an input to get an output. For supervised ML, input is tagged with expected outputs and we try to predict the outputs for future inputs too. Some of the examples of supervised learning are as follows:
#
# ![supML](../images/ai_supML.png)
#
# - Formally, the main task of the ML algorithm is to learn a mapping function from input to output variable/variables.
# $$\mathbf{Y = F(x)}$$
#
# ### Train/Test Data
#
# ![multiply](../images/child_multiply.jpeg)
# Let's take a simple scenario of teaching a child multiplication tables. You have taught everything from $1*1$ and $9*9$. Now how would you test whether the child has truly understood multiplication or simply memorised the tables? A good way to do that would be to give unseen data to test the child like $11*12$. Here we can say that $1*1$ to $9*9$ is the training data and $11*12$ is the test data.
#
# Similarly, in ML too, we would like to see if the ML algorithm has truly learnt the relationship between input and output. To do that, we divide the data into two parts - Training data and Test data. We use training data to learn the given model. And then, we use the test data to evaluate the model. What `learning a model` actually means, we will study it in other concepts down the line. Broadly there are two types of supervised learning tasks - Classification and Regression.
#
# The main difference between classification and regression is the form of output variable.
# If the output variable is discrete, it is classification, and if it is continuous, it is regression. You can think of discrete data as something which is counted and continuous data as something which is measured. Discrete data refers to things like - movie genres, categories of mail (spam/not spam) and so on. Continuous data refers to data like - height of a person, stock price, price of a house and so on.
#
# ### Classification
# - It involves finding a set of categories a new data point belongs to. The output value is a class or a category.
# - Examples
#
#      - Is the image - a cat or dog
#      - Deciding if an email is spam or not.
#      - Predicting whether a patient has cancer or not
#      - Predicting whether the value of a stock will rise or drop
#
# **Important: **
#  - Qualitative Output
#  - **Predefined Classes**
#
#
# ### Regression
# - It involves predicting a continuous value, given a set of inputs. The output value is continuous.
# - Example:
#      - Predict the stock price given different factors
#      - Predicting sales of a company for a given year
#      - Predicting runs/goals scored by a sports team
#      - Assigning credit rating
#
# **Important: **
# - Quantitative Output
# - **Previous input-output observations**
#
# ![classReg](../images/class_reg.jpg)
# Consider a situation, where we have the data of houses in the city.
# - Predicting the price of the house, given various factors like area of house, location, no of bedrooms, etc : Regression
# - Predicting if house will get sold in the next few months, given various factors like area of house, location, etc: Classification

# %% [markdown]
# #### FEEDBACK
# - Add the attribution of the HBR article from Andrew Ng for the image with ML usecases
# - Explain in slight more detail why train/test/validation and how they are important. Hope we are going deeper into help assessing validation metrics in later chapters. Refer: https://stanford.edu/~shervine/teaching/cs-229/cheatsheet-machine-learning-tips-and-tricks#classification-metrics

# %% [markdown]
# ## Quiz
#
# 1. Supervised ML where the target variable is discrete can be termed as:-
#
#   - Classification
#   - Regression
#
# Ans. 1
#
# 2. Regression is the type of Supervised ML where the target variable is
#
#   - Discrete
#   - Continuous
#
# Ans. 2

# %% [markdown]
# ## 4.2 Unsupervised ML
#
# In the previous chapter, you have learnt about supervised machine learning, where the inputs are tagged with specific outputs. What if, the inputs aren't tagged? Unsupervised machine learning is the machine learning task of inferring a function to describe hidden structure from "unlabeled" data (a classification or categorization is not included in the observations)
#
#  - Unsupervised learning is where you only have input data (X) and no corresponding output variables
#
#  - The goal for unsupervised learning is to model the underlying structure or distribution in the data in order to learn more about the data
#
# So in this case, we try to find homogeneous groups between data which we refer to as clusters. Typically, objects in a cluster exhibit similar behaviour.
#
# ### Clustering
# ***
#  - Unsupervised Learning Technique
#  - Grouping objects in clusters
#     - Similar Within Clusters
#     - Dissimilar between clusters
#
# ![cluster](../images/sup-vs-unsup.png)
#
# Examples:
#  - Segmenting customers into various groups
#  - Online shopping recommender system: Grouping things that are bought together
#  - Grouping Similar Animal Photos

# %% [markdown]
# ## 4.3 Semi-supervised ML
#
# - A mix of Supervised and Unsupervised Learning - only little data is labelled and the rest is unlabelled. The difference between the three types of learning: Supervised, Unsupervised and Semi-supervised is seen as below.
#
# ![comp_ssl](../images/comparison_ssl.jpg)Source: [Link](https://www.slideshare.net/Dataiku/dataiku-hadoop-summit-semisupervised-learning-with-hadoop-for-understanding-user-web-behaviours)
#
# The general process involved is to label the unlabelled data using the labelled data and then use the combined data for further processing. This process is called pseudo labelling.
#
# ![partial_labelling](../images/pseudo-labeling.png)
# Source: [Link](https://datawhatnow.com/pseudo-labeling-semi-supervised-learning/)
#
# ### Reinforcement Learning
#
#  - Used to solve interacting problems where the data observed up to time "**t**" is considered to *decide which action to take at time* "**t+1**"
#
#  - Also used for A.I. when training machines to perform tasks such as Walking, etc.
#
# Agent learns from the environment by interacting with it and receiving reward/punishment. Imagine a child walking towards a fireplace. It will feel warm and go closer towards the fire. This is like reward. When the child goes too close, it will feel hot and go back. This is punishment. Based on reward and punishment, the agent learn to navigate.
#
# ![mario](../images/mario.png)
#
# An agent playing the Mario game is an example of reinforcement learning.

# %% [markdown]
# #### FEEDBACK
# Semi Supervised learning is very sparsely researche and used in practical applications, with limited success. Do we want to keep it?

# %% [markdown]
# ## 4.4 Deep Learning
#
# ![intro_dl](../images/intro_dl2.png)
#
# Deep Learning is a subset of machine learning which has picked up in the recent years. One of the main pre-requisites for machine learning algorithms to perform well is to identify good features for data. Finding features is a pain-staking process. Deep learning, on the other hand, finds the best features directly from the data.
#
# ![dl_alphago](../images/alphago.jpg)
#
# Deep learning has found major success in lots of applications and solved problems which were considered hard for AI systems - image recognition, speech recognition. The best example is AlphaGo Zero which used deep learning and reinforcement learning to train an AI agent in the game of Go from scratch and beat the world champion. The game of Go was considered unlearnable by AI due to the millions of possible outcomes. We will decipher more on why deep learning works in the later part of the journey.
#
# Now that we have the building blocks of data science, let us map the entire data science journey that we are about to undertake and ask the important questions that every data scientist needs to ask.

# %% [markdown]
# ## 5. Mapping the Data Science journey

# %% [markdown]
# ## 5.1 To ML or not to ML
#
# ![ml_check](../images/check_ML.png)
#
# Before we even begin to map the journey of data science, we have to ask the pertinent question - do we need to apply ML to solve our problem? The flowchart shown is a handy guide to decide if the use case needs Machine Learning or not.
#
# Most of the time, we don't realize, but defining the right problem is extremely difficult. The ability to judge whether data science can be applied to a given problem is also an important quality of a data scientist.
#
# Some important things to ponder on before you apply ML (Source: [Link](https://hbr.org/2016/11/how-to-tell-if-machine-learning-can-solve-your-business-problem)):
# - Rule based approach gives you a good accuracy, ML gives you a marginal improvement.
#     - Here, a decision needs to be made if it is worth investing in a ML model. Most of the times, the business costs dictate whether ML is applied or not.
# - Do you require prediction in your problem or causal inference?
#     - If the business problem requires investigation of which causes what, then ML is not a good fit. ML is good only at prediction given a host of factors and can't do any causal inference.
# - Is the problem self-contained and insulated by outside influences
#     - The data you feed to your learning algorithm includes more or less all there is to the problem. If, in the future, the thing you’re trying to predict changes unexpectedly, and no longer matches prior patterns in the data, the algorithm will not know what to make of it.
#
# Good machine learning problems
#    - Predicting the likelihood that a certain type of user will click on a certain kind of ad
#    - Evaluating the extent to which a piece of text is similar to previous texts you have seen.
#
# Problems not fit for ML
#    - Predicting profits from the introduction of a completely new and revolutionary product line
#    - Extrapolating next year’s sales from past data, when an important new competitor just entered the market.
#
# Found a problem where ML could be applied? Congratulations! Now we shall look at the complete workflow of solving a problem.

# %% [markdown]
# #### FEEDBACK
# Can we add a sharper image?

# %% [markdown]
# ## 5.2 ML Workflow
#
# ![ml_workflow](../images/ml_workflow2.png)
#
# This would be a typical workflow for any ML problem. Let us take an example of real data and go through the different phases. During the course of the complete program, we will take up each of these phases in detail. We have abstracted the relevant phases into 4 major ones. These will help you understand the overview before we take a deep-dive into each of them in further detail in future concepts.
#
# ### Step 1 - Defining the problem
#
# An often underestimated step in the entire process, but a very crucial step to succeed. It is important to define the scope of the problem well. From the host of possible problems to solve, arriving at the right problem to solve is a valued skill.
#
#
# ### Step 2 - Prepare Data
#
# From the vast population of available data, find what are the missing values, and decide which columns are relevant for your processing and remove the rest. Find and engineer new features that you think might help in solving your problem better.
#
# ### Step 3 - Develop the Model
#
# This is the part which every scientist fantasizes to actually do. Develop the model on data and get the insights to answer the business questions defined earlier.
#
# ### Step 4 - Evaluate the Model
#
# Once the model is built, it is important to assess the model and see if it is working well on some test data before it is deployed on unseen data. How to assess the model and choose the best model is also important.

# %% [markdown]
# ## 5.3 The Path to Data Science
#
# Now that we have learnt a lot about data science - in terms of the overview, it is time to actually commence the journey to become a data scientist. This is just the beginning - there is programming, there is math and lots of hands-on projects and problems to solve. This DS journey map is a good way to measure your progress in the program.
#
# We will revisit this map as we trek along the different paths laid for us.
# ![ds_path](../images/ds_path.jpg)
#
# So why delay any longer? Let's begin the journey to learn = do data science.
